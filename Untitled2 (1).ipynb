# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from pylab import *

xmax = 7
xmin = -xmax

ymax = 7
ymin = -ymax

Nx=10
Ny=10

x=np.linspace(xmin, xmax, Nx)
y=np.linspace(ymin, ymax, Ny)

X, Y= np.meshgrid(x, y)

a=3

Bx= a*X-X**2
By= -Y
start=[[2,.75]]
fig0, ax0= plt.subplots()
strm = ax0.streamplot(x, y, Bx, By, color='g', linewidth=1.5)
strmS = ax0.streamplot(x, y, Bx, By, start_points=start, color='r', linewidth=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from pylab import *

xmax = 7
xmin = -xmax

ymax = 7
ymin = -ymax

Nx=10
Ny=10

x=np.linspace(xmin, xmax, Nx)
y=np.linspace(ymin, ymax, Ny)

X, Y= np.meshgrid(x, y)

a=3

Bx= a*X-X**3
By= 3*Y
start=[[2,.75]]
fig0, ax0= plt.subplots()
strm = ax0.streamplot(x, y, Bx, By, color='g', linewidth=1.5)
strmS = ax0.streamplot(x, y, Bx, By, start_points=start, color='r', linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/c8/ksccpg7s0rn1jbnjfsl71rx00000gn/T/ipykernel_20296/1787168977.py in <module>
#      24 start=[[2,.75]]
#      25 fig0, ax0= plt.subplots()
# ---> 26 strm = ax0.streamplot(x, y, Bx, By, color='g', linewidth=1.5)
#      27 strmS = ax0.streamplot(x, y, Bx, By, start_points=start, color='r', linewidth=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
